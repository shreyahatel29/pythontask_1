# %% [markdown]
# # Heading

# %% [markdown]
#  # Markdown task

# %% [markdown]
# ## Horitontal line

# %% [markdown]
# ***
# It shows horizontal line
# ***

# %% [markdown]
# ### Bold and Italic

# %% [markdown]
# **This shows bold text.**
#
# *This shows italic text.*

# %% [markdown]
# ### Highlight Code

# %% [markdown]
# `This is important!`

# %% [markdown]
# #### Ordered and Sub Ordered List

# %% [markdown]
# 1. Ordered List Item 1
# 2. Ordered List Item 2
# 3. Ordered List Item 3
#     1. Sub Ordered List Item 1
#     2. Sub Ordered List Item 2

# %% [markdown]
# #### Unordered List and Sub Unordered List

# %% [markdown]
# * Unordered List Item 1
# * Unordered List Item 2
# * Unordered List Item 3
#    * Sub Unordered List Item 1
#    * Sub Unordered List Item 2

# %% [markdown]
# #### Line Break

# %% [markdown]
# The line break syntax <br>
# is used to break the line.

# %% [markdown]
# #### Indenting

# %% [markdown]
# > This text will be indented when the markdown is rendered

# %% [markdown]
# #### Bullet Points

# %% [markdown]
# * This is main point
#    * This is sub point

# %% [markdown]
# #### Table

# %% [markdown]
# | Department_Id | Emp_name | Salary |
# |:--------------|:--------:|:------:|
# |  10001        |  John    | 32000  |
# |  10002        | Smith    | 25000  |

# %% [markdown]
# #### Font Color

# %% [markdown]
# <span style='color:Blue'>
# Blue is my favorite color.
# </span>

# %% [markdown]
# #### Background Color

# %% [markdown]
# <span style='background:yellow'>Background color is yellow.
# </span>

# %% [markdown]
# #### Blockquotes

# %% [markdown]
# > 1 Python
# >> 2 Java
# >>> 3 SQL
# >>>> 4 HTML

# %% [markdown]
# #### Image Insertion

# %% [markdown]
# ![blake-verdoorn-cssvEZacHvQ-unsplash.jpg](attachment:64c21624-0ade-4107-aa6c-6c847f318b35.jpg)
